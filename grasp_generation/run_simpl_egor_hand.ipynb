# %%
import os
import random
from utils.hand_model_lite import HandModelMJCFLite 
 
import numpy as np
import transforms3d
import torch
import trimesh
import json
import plotly.graph_objects as go

# %% [markdown]
# Here you need to choose your `hand_name`

# %%
mesh_path = "../data/meshdata"
# hand_name ="shadow_dexee"
hand_name ="DIP-Flex_opened_kinematics_simpl"
# hand_name ="DIP-Flex_opened_kinematics"
# hand_name = "robotiq_2"
# hand_name = "panda"

use_visual_mesh = True

if hand_name =="shadow_dexee":
    '''For shadow dexee'''
    data_path = "../data/dataset/shadow_dexee/"
    hand_file = "mjcf/shadow_dexee.xml"
    joint_names = [
                    "F0_J0", "F0_J1", "F0_J2", "F0_J3", "F1_J0", "F1_J1", "F1_J2", "F1_J3", "F2_J0", "F2_J1", "F2_J2", "F2_J3"
    ]

elif hand_name =="barret":
    ''' For BarretHand'''
    data_path = "../data/dataset/barret/"
    hand_file = "mjcf/barret.xml"
    joint_names = [
                    "wam_bhand_finger_1_prox_joint", "wam_bhand_finger_1_med_joint", "wam_bhand_finger_1_dist_joint", 
                    "wam_bhand_finger_2_prox_joint", "wam_bhand_finger_2_med_joint", "wam_bhand_finger_2_dist_joint",
                    "wam_bhand_finger_3_med_joint", "wam_bhand_finger_3_dist_joint"
    ]

elif hand_name =="DIP-Flex_opened_kinematics":
    ''' For Egorhand'''
    data_path = "../data/dataset/DIP-Flex_opened_kinematics"
    hand_file = "mjcf/DIP-Flex_opened_kinematics.xml"
    joint_names = [
                    "Joint_pinkie_abduction", "Joint_pinkie_PPflexion", "Joint_pinkie_DPflexion",
                    "Joint_index_abduction", "Joint_index_PPflexion", "Joint_index_DPflexion",
                    "Joint_thumb_rotation", "Joint_thumb_abduction", "Joint_thumb_PPflexion", "Joint_thumb_DPflexion"
    ]

elif hand_name == "robotiq_2":
    '''For robotiq'''
    data_path = "../data/dataset/robotiq_2/"
    hand_file = "mjcf/robotiq_2 simpl.xml"
    joint_names = [
                    "left_spring_link_joint", "left_follower",
                    "right_spring_link_joint", "right_follower_joint"
    ]

elif hand_name == "panda":
    '''For panda'''
    data_path = "../data/dataset/panda/"
    hand_file = "mjcf/panda.xml"
    joint_names = [
                    "finger_joint1", "finger_joint2"
    ]

elif hand_name == "shadow_dex_ee_simpl":
    data_path = "../data/dataset/shadow_dexee/"
    hand_file = "mjcf/shadow_dexee simpl.xml"
    joint_names = [
                    "F0_J0", "F0_J1", "F0_J2", "F0_J3", "F1_J0", "F1_J1", "F1_J2", "F1_J3", "F2_J0", "F2_J1", "F2_J2", "F2_J3"
    ]
elif hand_name =="barret_simpl":
    ''' For BarretHand'''
    data_path = "../data/dataset/barret/"
    hand_file = "mjcf/barret_simpl.xml"
    joint_names = [
                    "wam_bhand_finger_1_prox_joint", "wam_bhand_finger_1_med_joint", "wam_bhand_finger_1_dist_joint", 
                    "wam_bhand_finger_2_prox_joint", "wam_bhand_finger_2_med_joint", "wam_bhand_finger_2_dist_joint",
                    "wam_bhand_finger_3_med_joint", "wam_bhand_finger_3_dist_joint"
    ]

elif hand_name =="DIP-Flex_opened_kinematics_simpl":
    ''' For Egorhand'''
    data_path = "../data/dataset/DIP-Flex_opened_kinematics"
    hand_file = "./mjcf/DIP-Flex_opened_kinematics_simpl.xml"
    joint_names = [
                    "Joint_pinkie_abduction", "Joint_pinkie_PPflexion", "Joint_pinkie_DPflexion",
                    "Joint_index_abduction", "Joint_index_PPflexion", "Joint_index_DPflexion",
                    "Joint_thumb_rotation", "Joint_thumb_abduction", "Joint_thumb_PPflexion", "Joint_thumb_DPflexion"
    ]
 
    

translation_names = ['WRJTx', 'WRJTy', 'WRJTz']
rot_names = ['WRJRx', 'WRJRy', 'WRJRz']

# %%
hand_config = json.load(open('mjcf/' + hand_name + '.json', 'r'))
device = "cpu"

# %%
# Out:
# './mjcf/assets/DIP-Flex_opened_kinematics_simpl'

# %%
hand_model = HandModelMJCFLite(
    hand_file,
    "grasp_generation/mjcf/assets/" + hand_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:467, in File._get_asset_from_path(self, path)
#     466 try:
# --> 467     contents = self._parent.namescope.assets[path]
#     468 except KeyError:
#     469     # Construct the full path to the asset file, prefixed by the path to the
#     470     # model directory, and by `meshdir` or `texturedir` if appropriate.
#
# KeyError: 'base_link.stl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:177, in _ElementImpl.__init__(self, spec, parent, attributes)
#     176 try:
# --> 177     self._attributes[attribute_spec.name] = attribute_spec.type(
#     178         name=attribute_spec.name,
#     179         required=attribute_spec.required,
#     180         conflict_allowed=attribute_spec.conflict_allowed,
#     181         conflict_behavior=attribute_spec.conflict_behavior,
#     182         parent=self, value=value, **attribute_spec.other_kwargs)
#     183 except:  # pylint: disable=bare-except
#     184     # On failure, clear attributes already created
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:442, in File.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior, path_namespace)
#     441 self._path_namespace = path_namespace
# --> 442 super(File, self).__init__(name, required, parent, value,
#     443                            conflict_allowed, conflict_behavior)
#     444 parent.namescope.files.add(self)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:54, in _Attribute.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior)
#      53 self._conflict_behavior = conflict_behavior
# ---> 54 self._check_and_assign(value)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:60, in _Attribute._check_and_assign(self, new_value)
#      59 elif isinstance(new_value, str):
# ---> 60     self._assign_from_string(new_value)
#      61 else:
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:101, in _Attribute._assign_from_string(self, string)
#     100 def _assign_from_string(self, string):
# --> 101     self._assign(string)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:451, in File._assign(self, value)
#     450 if isinstance(value, six.string_types):
# --> 451     asset = self._get_asset_from_path(value)
#     452 elif isinstance(value, Asset):
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:482, in File._get_asset_from_path(self, path)
#     481     full_path = os.path.join(*path_parts)
# --> 482     contents = resources.GetResource(full_path)
#     483 return Asset(contents=contents, extension=extension, prefix=filename)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/io.py:24, in GetResource(name, mode)
#      23 def GetResource(name, mode='rb'):
# ---> 24     with open(name, mode=mode) as f:
#      25         return f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'assets/DIP-Flex_opened_kinematics/base_link.stl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:215, in _parse_children(xml_element, mjcf_element, escape_separators)
#     214 if child_spec.repeated or child_spec.on_demand:
# --> 215     mjcf_child = mjcf_element.add(xml_child.tag, **attributes)
#     216 else:
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:604, in _ElementImpl.add(self, element_name, **kwargs)
#     602     raise ValueError('A <{}> child already exists, please access it directly.'
#     603                      .format(element_name))
# --> 604 new_element = _make_element(child_spec, self, attributes=kwargs)
#     605 self._children.append(new_element)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:100, in _make_element(spec, parent, attributes)
#      99 else:
# --> 100     return _ElementImpl(spec, parent, attributes)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:192, in _ElementImpl.__init__(self, spec, parent, attributes)
#     189 message = (
#     190     'during initialization of attribute {!r} of element <{}>: {}'
#     191         .format(attribute_spec.name, self._spec.name, err))
# --> 192 six.reraise(err_type, err_type(message), traceback)
#
# File ~/miniconda3/envs/dexgraspnet_8/lib/python3.8/site-packages/six.py:718, in reraise(tp, value, tb)
#     717 if value.__traceback__ is not tb:
# --> 718     raise value.with_traceback(tb)
#     719 raise value
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:177, in _ElementImpl.__init__(self, spec, parent, attributes)
#     176 try:
# --> 177     self._attributes[attribute_spec.name] = attribute_spec.type(
#     178         name=attribute_spec.name,
#     179         required=attribute_spec.required,
#     180         conflict_allowed=attribute_spec.conflict_allowed,
#     181         conflict_behavior=attribute_spec.conflict_behavior,
#     182         parent=self, value=value, **attribute_spec.other_kwargs)
#     183 except:  # pylint: disable=bare-except
#     184     # On failure, clear attributes already created
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:442, in File.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior, path_namespace)
#     441 self._path_namespace = path_namespace
# --> 442 super(File, self).__init__(name, required, parent, value,
#     443                            conflict_allowed, conflict_behavior)
#     444 parent.namescope.files.add(self)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:54, in _Attribute.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior)
#      53 self._conflict_behavior = conflict_behavior
# ---> 54 self._check_and_assign(value)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:60, in _Attribute._check_and_assign(self, new_value)
#      59 elif isinstance(new_value, str):
# ---> 60     self._assign_from_string(new_value)
#      61 else:
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:101, in _Attribute._assign_from_string(self, string)
#     100 def _assign_from_string(self, string):
# --> 101     self._assign(string)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:451, in File._assign(self, value)
#     450 if isinstance(value, six.string_types):
# --> 451     asset = self._get_asset_from_path(value)
#     452 elif isinstance(value, Asset):
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:482, in File._get_asset_from_path(self, path)
#     481     full_path = os.path.join(*path_parts)
# --> 482     contents = resources.GetResource(full_path)
#     483 return Asset(contents=contents, extension=extension, prefix=filename)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/io.py:24, in GetResource(name, mode)
#      23 def GetResource(name, mode='rb'):
# ---> 24     with open(name, mode=mode) as f:
#      25         return f.read()
#
# FileNotFoundError: during initialization of attribute 'file' of element <mesh>: [Errno 2] No such file or directory: 'assets/DIP-Flex_opened_kinematics/base_link.stl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 hand_model = HandModelMJCFLite(
#       2     hand_file,
#       3     "assets/" + hand_name)
#
# File ~/prj/DexGraspNet/grasp_generation/utils/hand_model_lite.py:30, in HandModelMJCFLite.__init__(self, mjcf_path, mesh_path, device)
#      16 """
#      17 Create a Lite Hand Model for a MJCF robot
#      18
#    (...)
#      26     device for torch tensors
#      27 """
#      29 self.device = device
# ---> 30 self.chain = pk.build_chain_from_mjcf(
#      31     open(mjcf_path).read()).to(dtype=torch.float, device=device)
#      32 self.n_dofs = len(self.chain.get_joint_parameter_names())
#      34 self.mesh = {}
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf.py:83, in build_chain_from_mjcf(data)
#      69 def build_chain_from_mjcf(data):
#      70     """
#      71     Build a Chain object from MJCF data.
#      72
#    (...)
#      81         Chain object created from MJCF.
#      82     """
# ---> 83     model = mjcf_parser.from_xml_string(data)
#      84     root_body = model.worldbody.body[0]
#      85     root_frame = frame.Frame(root_body.name + "_frame",
#      86                              link=body_to_link(root_body),
#      87                              joint=frame.Joint())
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:54, in from_xml_string(xml_string, escape_separators, model_dir, resolve_references, assets)
#      35 """Parses an XML string into an MJCF object model.
#      36
#      37 Args:
#    (...)
#      51   An `mjcf.RootElement`.
#      52 """
#      53 xml_root = etree.fromstring(xml_string)
# ---> 54 return _parse(xml_root, escape_separators,
#      55               model_dir=model_dir,
#      56               resolve_references=resolve_references,
#      57               assets=assets)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:174, in _parse(xml_root, escape_separators, model_dir, resolve_references, assets)
#     171     model = None
#     172 mjcf_root = element.RootElement(
#     173     model=model, model_dir=model_dir, assets=assets)
# --> 174 _parse_children(xml_root, mjcf_root, escape_separators)
#     176 # Merge in the included XML files.
#     177 for included_mjcf in to_include:
#     178     # The included MJCF might have been automatically assigned a model name
#     179     # that conficts with that of `mjcf_root`, so we override it here.
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:224, in _parse_children(xml_element, mjcf_element, escape_separators)
#     221     message = ('Line {}: error while parsing element <{}>: {}'
#     222                .format(xml_child.sourceline, xml_child.tag, err))
#     223     six.reraise(err_type, err_type(message), traceback)
# --> 224 _parse_children(xml_child, mjcf_child, escape_separators)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:223, in _parse_children(xml_element, mjcf_element, escape_separators)
#     220     err_type, err, traceback = sys.exc_info()
#     221     message = ('Line {}: error while parsing element <{}>: {}'
#     222                .format(xml_child.sourceline, xml_child.tag, err))
# --> 223     six.reraise(err_type, err_type(message), traceback)
#     224 _parse_children(xml_child, mjcf_child, escape_separators)
#
# File ~/miniconda3/envs/dexgraspnet_8/lib/python3.8/site-packages/six.py:718, in reraise(tp, value, tb)
#     716         value = tp()
#     717     if value.__traceback__ is not tb:
# --> 718         raise value.with_traceback(tb)
#     719     raise value
#     720 finally:
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/parser.py:215, in _parse_children(xml_element, mjcf_element, escape_separators)
#     213     attributes = dict(xml_child.attrib)
#     214 if child_spec.repeated or child_spec.on_demand:
# --> 215     mjcf_child = mjcf_element.add(xml_child.tag, **attributes)
#     216 else:
#     217     mjcf_child = getattr(mjcf_element, xml_child.tag)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:604, in _ElementImpl.add(self, element_name, **kwargs)
#     601 if not (child_spec.repeated or need_new_on_demand):
#     602     raise ValueError('A <{}> child already exists, please access it directly.'
#     603                      .format(element_name))
# --> 604 new_element = _make_element(child_spec, self, attributes=kwargs)
#     605 self._children.append(new_element)
#     606 self.namescope.increment_revision()
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:100, in _make_element(spec, parent, attributes)
#      98     return _ActuatorElement(spec, parent, attributes)
#      99 else:
# --> 100     return _ElementImpl(spec, parent, attributes)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:192, in _ElementImpl.__init__(self, spec, parent, attributes)
#     188 err_type, err, traceback = sys.exc_info()
#     189 message = (
#     190     'during initialization of attribute {!r} of element <{}>: {}'
#     191         .format(attribute_spec.name, self._spec.name, err))
# --> 192 six.reraise(err_type, err_type(message), traceback)
#
# File ~/miniconda3/envs/dexgraspnet_8/lib/python3.8/site-packages/six.py:718, in reraise(tp, value, tb)
#     716         value = tp()
#     717     if value.__traceback__ is not tb:
# --> 718         raise value.with_traceback(tb)
#     719     raise value
#     720 finally:
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/element.py:177, in _ElementImpl.__init__(self, spec, parent, attributes)
#     175     value = attributes[attribute_spec.name]
#     176 try:
# --> 177     self._attributes[attribute_spec.name] = attribute_spec.type(
#     178         name=attribute_spec.name,
#     179         required=attribute_spec.required,
#     180         conflict_allowed=attribute_spec.conflict_allowed,
#     181         conflict_behavior=attribute_spec.conflict_behavior,
#     182         parent=self, value=value, **attribute_spec.other_kwargs)
#     183 except:  # pylint: disable=bare-except
#     184     # On failure, clear attributes already created
#     185     for attribute_obj in six.itervalues(self._attributes):
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:442, in File.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior, path_namespace)
#     439 def __init__(self, name, required, parent, value,
#     440              conflict_allowed, conflict_behavior, path_namespace):
#     441     self._path_namespace = path_namespace
# --> 442     super(File, self).__init__(name, required, parent, value,
#     443                                conflict_allowed, conflict_behavior)
#     444     parent.namescope.files.add(self)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:54, in _Attribute.__init__(self, name, required, parent, value, conflict_allowed, conflict_behavior)
#      52 self._conflict_allowed = conflict_allowed
#      53 self._conflict_behavior = conflict_behavior
# ---> 54 self._check_and_assign(value)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:60, in _Attribute._check_and_assign(self, new_value)
#      58     self.clear()
#      59 elif isinstance(new_value, str):
# ---> 60     self._assign_from_string(new_value)
#      61 else:
#      62     self._assign(new_value)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:101, in _Attribute._assign_from_string(self, string)
#     100 def _assign_from_string(self, string):
# --> 101     self._assign(string)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:451, in File._assign(self, value)
#     449 else:
#     450     if isinstance(value, six.string_types):
# --> 451         asset = self._get_asset_from_path(value)
#     452     elif isinstance(value, Asset):
#     453         asset = value
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/attribute.py:482, in File._get_asset_from_path(self, path)
#     480     path_parts.append(path)
#     481     full_path = os.path.join(*path_parts)
# --> 482     contents = resources.GetResource(full_path)
#     483 return Asset(contents=contents, extension=extension, prefix=filename)
#
# File ~/prj/DexGraspNet/thirdparty/pytorch_kinematics/pytorch_kinematics/mjcf_parser/io.py:24, in GetResource(name, mode)
#      23 def GetResource(name, mode='rb'):
# ---> 24     with open(name, mode=mode) as f:
#      25         return f.read()
#
# FileNotFoundError: Line 45: error while parsing element <mesh>: during initialization of attribute 'file' of element <mesh>: [Errno 2] No such file or directory: 'assets/DIP-Flex_opened_kinematics/base_link.stl'

# %%
grasp_code_list = []
for code in os.listdir(data_path):
    grasp_code_list.append(code[:-4])

print(grasp_code_list)
# Out:
# ['ddg-gd_banana_poisson_002', 'core-mug-8570d9a8d24cb0acbebd3c0c0c70fb03', 'sem-Bottle-437678d4bc6be981c8724d5673a063a6', 'mujoco-Ecoforms_Plant_Plate_S11Turquoise', 'hummer', 'sem-Camera-7bff4fd4dc53de7496dece3f86cb5dd5', 'pliers', 'screwdriver']

# %%
grasp_code = random.choice(grasp_code_list)
grasp_data = np.load(
    os.path.join(data_path, grasp_code+".npy"), allow_pickle=True)
object_mesh_origin = trimesh.load(os.path.join(
    mesh_path, grasp_code, "coacd/decomposed.obj"))
print(grasp_code)

print(grasp_data)
print(len(grasp_data))

# %%
index = random.randint(0, len(grasp_data) - 1)
# index = 3

qpos = grasp_data[index]['qpos']
print(index)
rot = np.array(transforms3d.euler.euler2mat(
    *[qpos[name] for name in rot_names]))
rot = rot[:, :2].T.ravel().tolist()
hand_pose = torch.tensor([qpos[name] for name in translation_names] + rot + [qpos[name]
                         for name in joint_names], dtype=torch.float, device="cpu").unsqueeze(0)
hand_model.set_parameters(hand_pose)
hand_mesh = hand_model.get_trimesh_data(0)
object_mesh = object_mesh_origin.copy().apply_scale(grasp_data[index]["scale"])

# Задаем цвета (RGB в формате [R, G, B, A], где значения от 0.0 до 1.0)
hand_color = [0.7, 0.7, 0.7, 1.0]  # Красноватый цвет для руки
object_color = [0.2, 0.5, 0.8, 1.0]  # Голубоватый цвет для объекта

# Применяем цвета к мешам
hand_mesh.visual.face_colors = hand_color
object_mesh.visual.face_colors = object_color

# %%
hand_en_plotly = hand_model.get_plotly_data(i=0, opacity=1, color='lightblue')
 
fig = go.Figure( hand_en_plotly  )
fig.show()

# %%
(hand_mesh+object_mesh).show()
